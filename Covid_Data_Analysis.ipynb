# %%
import pandas as pd
import seaborn as sns 
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
df_Tests=pd.read_excel("Desktop/Covid_Data.xlsx","Tests",parse_dates=["date"])

# %%
# VEIWING THE DATABASE

# %%
df_Tests.set_index("date",inplace=True)

# %%
df_Tests.head()
# Out:
#            iso_code continent     location  new_tests  total_tests  \
# date
# 2020-02-24      AFG      Asia  Afghanistan        NaN          NaN
# 2020-02-25      AFG      Asia  Afghanistan        NaN          NaN
# 2020-02-26      AFG      Asia  Afghanistan        NaN          NaN
# 2020-02-27      AFG      Asia  Afghanistan        NaN          NaN
# 2020-02-28      AFG      Asia  Afghanistan        NaN          NaN
#
#             positive_rate  tests_per_case
# date
# 2020-02-24            NaN             NaN
# 2020-02-25            NaN             NaN
# 2020-02-26            NaN             NaN
# 2020-02-27            NaN             NaN
# 2020-02-28            NaN             NaN

# %%
# GROUPING THE DATABASE OF THE BIG SEVEN ECONOMIES FOR THE TESTS CONDUCTED

# %%
group_test=df_Tests.groupby("location")
group_test_India=group_test.get_group("India")
group_test_US=group_test.get_group("United States")
group_test_China=group_test.get_group("China")
group_test_UK=group_test.get_group("United Kingdom")
group_test_Japan=group_test.get_group("Japan")
group_test_Germany=group_test.get_group("Germany")
group_test_France=group_test.get_group("France")

# %%
#VISUALISING THE NEW TESTS DONE BY THE BIG SIX ECONOMIES

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_test_India["new_tests"],x=group_test_India.index,color="blue",label="India")
sns.lineplot(y=group_test_US["new_tests"],x=group_test_US.index,color="red",label="US",zorder=2)
sns.lineplot(y=group_test_China["new_tests"],x=group_test_China.index,color="yellow",label="China")
sns.lineplot(y=group_test_UK["new_tests"],x=group_test_UK.index,color="black",label="UK")
sns.lineplot(y=group_test_Japan["new_tests"],x=group_test_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_test_Germany["new_tests"],x=group_test_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_test_France["new_tests"],x=group_test_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("Daily Tests",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Dates",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB",zorder=1)
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("Tests In Big Seven Economies",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")

plt.show()

# %%
# VISUALISING THE TESTS MORE CLEARLY

# %%
# %matplotlib inline
group_test_India["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In India",color="blue")
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_France["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In France",color="purple")
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_Japan["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In Japan",color="green")
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_UK["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In UK",color="black")
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_US["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In US",color="red")
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_China["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In China",color="yellow",lw=6)
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_Germany["new_tests"].plot.area(figsize=(10,3),subplots=True,label="Daily Tests In Germany",color="orange",lw=6)
plt.title("Tests Recorded")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()

# %%
max_test_in_India=group_test_India["new_tests"].max()
max_test_in_China=group_test_China["new_tests"].max()
max_test_in_France=group_test_France["new_tests"].max()
max_test_in_Germany=group_test_Germany["new_tests"].max()
max_test_in_Japan=group_test_Japan["new_tests"].max()
max_test_in_UK=group_test_UK["new_tests"].max()
max_test_in_US=group_test_US["new_tests"].max()

# %%
mean_test_in_India=group_test_India["new_tests"].mean(skipna=True)
mean_test_in_China=group_test_China["new_tests"].mean(skipna=True)
mean_test_in_France=group_test_France["new_tests"].mean(skipna=True)
mean_test_in_Germany=group_test_Germany["new_tests"].mean(skipna=True)
mean_test_in_Japan=group_test_Japan["new_tests"].mean(skipna=True)
mean_test_in_UK=group_test_UK["new_tests"].mean(skipna=True)
mean_test_in_US=group_test_US["new_tests"].mean(skipna=True)

# %%
median_test_in_India=group_test_India["new_tests"].median(skipna=True)
median_test_in_China=group_test_China["new_tests"].median(skipna=True)
median_test_in_France=group_test_France["new_tests"].median(skipna=True)
median_test_in_Germany=group_test_Germany["new_tests"].median(skipna=True)
median_test_in_Japan=group_test_Japan["new_tests"].median(skipna=True)
median_test_in_UK=group_test_UK["new_tests"].median(skipna=True)
median_test_in_US=group_test_US["new_tests"].median(skipna=True)
# Out:
# c:\users\karan\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\users\karan\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
sum_test_in_India=group_test_India["new_tests"].sum(skipna=True)
sum_test_in_China=group_test_China["new_tests"].sum(skipna=True)
sum_test_in_France=group_test_France["new_tests"].sum(skipna=True)
sum_test_in_Germany=group_test_Germany["new_tests"].sum(skipna=True)
sum_test_in_Japan=group_test_Japan["new_tests"].sum(skipna=True)
sum_test_in_UK=group_test_UK["new_tests"].sum(skipna=True)
sum_test_in_US=group_test_US["new_tests"].sum(skipna=True)

# %%
sum_of_tests_by_big_seven=[sum_test_in_US,sum_test_in_UK,sum_test_in_Japan,sum_test_in_India,sum_test_in_Germany,sum_test_in_France,sum_test_in_China]
median_of_tests_by_big_seven=[median_test_in_US,median_test_in_UK,median_test_in_Japan,median_test_in_India,median_test_in_Germany,median_test_in_France,median_test_in_China]
mean_of_tests_by_big_seven=[mean_test_in_US,mean_test_in_UK,mean_test_in_Japan,mean_test_in_India,mean_test_in_Germany,mean_test_in_France,mean_test_in_China]
max_of_tests_by_big_seven=[max_test_in_US,max_test_in_UK,max_test_in_Japan,max_test_in_India,max_test_in_Germany,max_test_in_France,max_test_in_China]

# %%
statistics_tests={
    "Total Tests":sum_of_tests_by_big_seven,
    "Median Tests":median_of_tests_by_big_seven,
    "Mean Tests":mean_of_tests_by_big_seven,
    "Maximum Tests In a Day":max_of_tests_by_big_seven
}

# %%
df_statistics_tests=pd.DataFrame(statistics_tests)
df_statistics_tests.index=["United States","United Kingdom","Japan","India","Germany","France","China"]
df_statistics_tests.index.name="Country"
df_statistics_tests.columns.name="Statistics"
df_statistics_tests.style.highlight_max(color='yellow')
# Out:
# <style type="text/css">
# #T_73a98_row0_col0, #T_73a98_row0_col2, #T_73a98_row3_col1, #T_73a98_row3_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_73a98_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Total Tests</th>
#       <th class="col_heading level0 col1" >Median Tests</th>
#       <th class="col_heading level0 col2" >Mean Tests</th>
#       <th class="col_heading level0 col3" >Maximum Tests In a Day</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73a98_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_73a98_row0_col0" class="data row0 col0" >731505528.000000</td>
# ...

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_test_India["positive_rate"],x=group_test_India.index,color="blue",label="India")
sns.lineplot(y=group_test_US["positive_rate"],x=group_test_US.index,color="red",label="US")
sns.lineplot(y=group_test_China["positive_rate"],x=group_test_China.index,color="yellow",label="China")
sns.lineplot(y=group_test_UK["positive_rate"],x=group_test_UK.index,color="black",label="UK")
sns.lineplot(y=group_test_Japan["positive_rate"],x=group_test_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_test_Germany["positive_rate"],x=group_test_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_test_France["positive_rate"],x=group_test_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("Positive Rate",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Dates",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("Covid-19 Positive Rate In Big Seven Economies",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")

plt.show()

# %%
# %matplotlib inline
group_test_India["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In India",color="blue")
plt.title("Daily Positive Rate")
plt.ylabel("Daily Tests")
plt.legend()
plt.show()
group_test_France["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In France",color="purple")
plt.title("Daily Positive Rate")
plt.ylabel("Positive Rate")
plt.legend()
plt.show()
group_test_UK["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In UK",color="black")
plt.title("Daily Positive Rate")
plt.ylabel("Positive Rate")
plt.legend()
plt.show()
group_test_US["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In US",color="red")
plt.title("Daily Positive Rate")
plt.ylabel("Positive Rate")
plt.legend()
plt.show()
group_test_Japan["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In Japan",color="green")
plt.title("Daily Positive Rate")
plt.ylabel("Positive Rate")
plt.legend()
plt.show()
group_test_China["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In China",color="yellow",stacked=True,lw=6)
plt.title("Daily Positive Rate")
plt.ylabel("Positive Rate")
plt.legend()
plt.show()
group_test_Germany["positive_rate"].plot.area(figsize=(10,3),subplots=True,label="Daily Positive Rate In Germany",color="orange",lw=2)
plt.title("Daily Positive Rate")
plt.ylabel("Positive Rate")
plt.legend()
plt.show()

# %%
max_positve_rate_in_India=group_test_India["positive_rate"].max()
max_positve_rate_in_China=group_test_China["positive_rate"].max()
max_positve_rate_in_France=group_test_France["positive_rate"].max()
max_positve_rate_in_Germany=group_test_Germany["positive_rate"].max()
max_positve_rate_in_Japan=group_test_Japan["positive_rate"].max()
max_positve_rate_in_UK=group_test_UK["positive_rate"].max()
max_positve_rate_in_US=group_test_US["positive_rate"].max()

# %%
mean_positve_rate_in_India=group_test_India["positive_rate"].mean(skipna=True)
mean_positve_rate_in_China=group_test_China["positive_rate"].mean(skipna=True)
mean_positve_rate_in_France=group_test_France["positive_rate"].mean(skipna=True)
mean_positve_rate_in_Germany=group_test_Germany["positive_rate"].mean(skipna=True)
mean_positve_rate_in_Japan=group_test_Japan["positive_rate"].mean(skipna=True)
mean_positve_rate_in_UK=group_test_UK["positive_rate"].mean(skipna=True)
mean_positve_rate_in_US=group_test_US["positive_rate"].mean(skipna=True)

# %%
median_positve_rate_in_India=group_test_India["positive_rate"].median(skipna=True)
median_positve_rate_in_China=group_test_China["positive_rate"].median(skipna=True)
median_positve_rate_in_France=group_test_France["positive_rate"].median(skipna=True)
median_positve_rate_in_Germany=group_test_Germany["positive_rate"].median(skipna=True)
median_positve_rate_in_Japan=group_test_Japan["positive_rate"].median(skipna=True)
median_positve_rate_in_UK=group_test_UK["positive_rate"].median(skipna=True)
median_positve_rate_in_US=group_test_US["positive_rate"].median(skipna=True)
# Out:
# c:\users\karan\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
median_positive_rate_by_big_seven=[median_positve_rate_in_US,median_positve_rate_in_UK,median_positve_rate_in_Japan,median_positve_rate_in_India,median_positve_rate_in_Germany,median_positve_rate_in_France,median_positve_rate_in_China]                                                                     
mean_positive_rate_by_big_seven=[mean_positve_rate_in_US,mean_positve_rate_in_UK,mean_positve_rate_in_Japan,mean_positve_rate_in_India,mean_positve_rate_in_Germany,mean_positve_rate_in_France,mean_positve_rate_in_China]
max_positive_rate_by_big_seven=[max_positve_rate_in_US,max_positve_rate_in_UK,max_positve_rate_in_Japan,max_positve_rate_in_India,max_positve_rate_in_Germany,max_positve_rate_in_France,max_positve_rate_in_China]

# %%
statistics_positive_rate={
    "Average Positive Rate":mean_positive_rate_by_big_seven,
    "Median Positive Rate":median_positive_rate_by_big_seven,
    "Maximum Positive Rate In A Day":max_positive_rate_by_big_seven
}

# %%
df_statistics_positive_rate=pd.DataFrame(statistics_positive_rate)
df_statistics_positive_rate.index=["United States","United Kingdom","Japan","India","Germany","France","China"]
df_statistics_positive_rate.index.name="Country"
df_statistics_positive_rate.columns.name="Statistics"
df_statistics_positive_rate.style.highlight_max(color='pink')
# Out:
# <style type="text/css">
# #T_e8c79_row0_col0, #T_e8c79_row1_col2, #T_e8c79_row4_col1 {
#   background-color: pink;
# }
# </style>
# <table id="T_e8c79_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Average Positive Rate</th>
#       <th class="col_heading level0 col1" >Median Positive Rate</th>
#       <th class="col_heading level0 col2" >Maximum Positive Rate In A Day</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8c79_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_e8c79_row0_col0" class="data row0 col0" >0.073512</td>
#       <td id="T_e8c79_row0_col1" class="data row0 col1" >0.061800</td>
# ...

# %% [markdown]
# VISUALISING THE TESTS PER CASE CONDUCTED BY THE BIG SIX ECONOMIES

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_test_India["tests_per_case"],x=group_test_India.index,color="blue",label="India")
sns.lineplot(y=group_test_US["tests_per_case"],x=group_test_US.index,color="red",label="US")
sns.lineplot(y=group_test_China["tests_per_case"],x=group_test_China.index,color="yellow",label="China")
sns.lineplot(y=group_test_UK["tests_per_case"],x=group_test_UK.index,color="black",label="UK")
sns.lineplot(y=group_test_Japan["tests_per_case"],x=group_test_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_test_Germany["tests_per_case"],x=group_test_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_test_France["tests_per_case"],x=group_test_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("Tests Per Case",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Dates",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("Test Per Case In The Big Seven Economies",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.show()

# %%
# %matplotlib inline
group_test_India["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In India",color="blue")
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()
group_test_France["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In France",color="purple")
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()
group_test_UK["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In UK",color="black")
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()
group_test_US["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In US",color="red")
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()
group_test_Japan["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In Japan",color="green")
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()
group_test_China["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In China",color="yellow",lw=6)
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()
group_test_Germany["tests_per_case"].plot.area(figsize=(10,3),subplots=True,label="Daily Test Per Case Rate In Germany",color="orange")
plt.title("Tests Per Case")
plt.ylabel("Tests Per Case")
plt.legend()
plt.show()

# %% [markdown]
# CREATING PIVOT TABLE

# %%
tests_pivot_table=df_Tests.pivot_table(index="continent",values=["positive_rate","tests_per_case"],aggfunc="mean",dropna=True)
tests_pivot_table.columns=["Positive Rate","Tests Per Case"]
tests_pivot_table.index.name="Continents"
tests_pivot_table.columns.name="Statistics"

# %%
tests_pivot_table.style.highlight_max(color="green")
# Out:
# <style type="text/css">
# #T_708c9_row4_col1, #T_708c9_row5_col0 {
#   background-color: green;
# }
# </style>
# <table id="T_708c9_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Positive Rate</th>
#       <th class="col_heading level0 col1" >Tests Per Case</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Continents</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_708c9_level0_row0" class="row_heading level0 row0" >Africa</th>
#       <td id="T_708c9_row0_col0" class="data row0 col0" >0.085617</td>
#       <td id="T_708c9_row0_col1" class="data row0 col1" >51.447664</td>
#     </tr>
#     <tr>
#       <th id="T_708c9_level0_row1" class="row_heading level0 row1" >Asia</th>
#       <td id="T_708c9_row1_col0" class="data row1 col0" >0.067940</td>
# ...

# %%
# %matplotlib inline
tests_pivot_table["Positive Rate"].plot(kind="bar",color=["red","red","red","red","green","yellow"],hatch="*",edgecolor="black")
plt.xticks(rotation="horizontal",size=10,fontstyle="italic",fontname="Comic Sans MS")
plt.title("Average Positive Rate In The Continents",fontname="Comic Sans MS")
plt.ylabel("Average Positive Rate",fontname="Comic Sans MS",size=13)
plt.show()

# %% [raw]
# _______________________________________________________________________________________________________________________________

# %%
df_Deaths=pd.read_excel("Desktop/Covid_Data.xlsx","Deaths",parse_dates=["date"])

# %%
df_Deaths.set_index("date",inplace=True)

# %% [markdown]
# VIEWING THE DATABASE

# %%
df_Deaths.head()
# Out:
#            iso_code continent     location  total_deaths  new_deaths
# date
# 2020-02-24      AFG      Asia  Afghanistan           NaN         NaN
# 2020-02-25      AFG      Asia  Afghanistan           NaN         NaN
# 2020-02-26      AFG      Asia  Afghanistan           NaN         NaN
# 2020-02-27      AFG      Asia  Afghanistan           NaN         NaN
# 2020-02-28      AFG      Asia  Afghanistan           NaN         NaN

# %% [markdown]
# GROUPING THE DEATHS THAT TOOK PLACE IN THE BIG SEVEN ECONOMIES

# %%
group_deaths=df_Deaths.groupby("location")
group_deaths_India=group_deaths.get_group("India")
group_deaths_US=group_deaths.get_group("United States")
group_deaths_China=group_deaths.get_group("China")
group_deaths_UK=group_deaths.get_group("United Kingdom")
group_deaths_Japan=group_deaths.get_group("Japan")
group_deaths_Germany=group_deaths.get_group("Germany")
group_deaths_France=group_deaths.get_group("France")

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_deaths_India["new_deaths"],x=group_deaths_India.index,color="blue",label="India")
sns.lineplot(y=group_deaths_US["new_deaths"],x=group_deaths_US.index,color="red",label="US")
sns.lineplot(y=group_deaths_China["new_deaths"],x=group_deaths_China.index,color="yellow",label="China")
sns.lineplot(y=group_deaths_UK["new_deaths"],x=group_deaths_UK.index,color="black",label="UK")
sns.lineplot(y=group_deaths_Japan["new_deaths"],x=group_deaths_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_deaths_Germany["new_deaths"],x=group_deaths_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_deaths_France["new_deaths"],x=group_deaths_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("New Deaths",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Date",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("Deaths In Big Seven Economies",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.show()

# %%
# %matplotlib inline
group_deaths_India["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In India",color="blue",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()
group_deaths_France["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In France",color="purple",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()
group_deaths_UK["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In UK",color="black",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()
group_deaths_US["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In US",color="red",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()
group_deaths_Japan["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In Japan",color="green",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()
group_deaths_Germany["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In Germany",color="orange",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()
group_deaths_China["new_deaths"].plot.area(figsize=(10,3),subplots=True,label="Daily Deaths In China",color="yellow",stacked=False)
plt.ylabel("Daily Deaths")
plt.legend()
plt.show()

# %%
max_new_deaths_in_India=group_deaths_India["new_deaths"].max(skipna=True)
max_new_deaths_in_China=group_deaths_China["new_deaths"].max(skipna=True)
max_new_deaths_in_France=group_deaths_France["new_deaths"].max(skipna=True)
max_new_deaths_in_Germany=group_deaths_Germany["new_deaths"].max(skipna=True)
max_new_deaths_in_Japan=group_deaths_Japan["new_deaths"].max(skipna=True)
max_new_deaths_in_UK=group_deaths_UK["new_deaths"].max(skipna=True)
max_new_deaths_in_US=group_deaths_US["new_deaths"].max(skipna=True)

# %%
mean_new_deaths_in_India=group_deaths_India["new_deaths"].mean(skipna=True)
mean_new_deaths_in_China=group_deaths_China["new_deaths"].mean(skipna=True)
mean_new_deaths_in_France=group_deaths_France["new_deaths"].mean(skipna=True)
mean_new_deaths_in_Germany=group_deaths_Germany["new_deaths"].mean(skipna=True)
mean_new_deaths_in_Japan=group_deaths_Japan["new_deaths"].mean(skipna=True)
mean_new_deaths_in_UK=group_deaths_UK["new_deaths"].mean(skipna=True)
mean_new_deaths_in_US=group_deaths_US["new_deaths"].mean(skipna=True)

# %%
median_new_deaths_in_India=group_deaths_India["new_deaths"].median(skipna=True)
median_new_deaths_in_China=group_deaths_China["new_deaths"].median(skipna=True)
median_new_deaths_in_France=group_deaths_France["new_deaths"].median(skipna=True)
median_new_deaths_in_Germany=group_deaths_Germany["new_deaths"].median(skipna=True)
median_new_deaths_in_Japan=group_deaths_Japan["new_deaths"].median(skipna=True)
median_new_deaths_in_UK=group_deaths_UK["new_deaths"].median(skipna=True)
median_new_deaths_in_US=group_deaths_US["new_deaths"].median(skipna=True)

# %%
sum_new_deaths_in_India=group_deaths_India["new_deaths"].sum(skipna=True)
sum_new_deaths_in_China=group_deaths_China["new_deaths"].sum(skipna=True)
sum_new_deaths_in_France=group_deaths_France["new_deaths"].sum(skipna=True)
sum_new_deaths_in_Germany=group_deaths_Germany["new_deaths"].sum(skipna=True)
sum_new_deaths_in_Japan=group_deaths_Japan["new_deaths"].sum(skipna=True)
sum_new_deaths_in_UK=group_deaths_UK["new_deaths"].sum(skipna=True)
sum_new_deaths_in_US=group_deaths_US["new_deaths"].sum(skipna=True)

# %%
max_new_deaths_by_big_seven=[max_new_deaths_in_US,max_new_deaths_in_UK,max_new_deaths_in_Japan,max_new_deaths_in_India,max_new_deaths_in_Germany,max_new_deaths_in_France,max_new_deaths_in_China]                                                       
mean_new_deaths_by_big_seven=[mean_new_deaths_in_US,mean_new_deaths_in_UK,mean_new_deaths_in_Japan,mean_new_deaths_in_India,mean_new_deaths_in_Germany,mean_new_deaths_in_France,mean_new_deaths_in_China]
sum_new_deaths_by_big_seven=[sum_new_deaths_in_US,sum_new_deaths_in_UK,sum_new_deaths_in_Japan,sum_new_deaths_in_India,sum_new_deaths_in_Germany,sum_new_deaths_in_France,sum_new_deaths_in_China]
median_new_deaths_by_big_seven=[median_new_deaths_in_US,median_new_deaths_in_UK,median_new_deaths_in_Japan,median_new_deaths_in_India,median_new_deaths_in_Germany,median_new_deaths_in_France,median_new_deaths_in_China]

# %%
statistics_death_rate={
    "Average Deaths":mean_new_deaths_by_big_seven,
    "Median Deaths":median_new_deaths_by_big_seven,
    "Maximum Deaths In A Day":max_new_deaths_by_big_seven,
    "Total Deaths":sum_new_deaths_by_big_seven
}

# %%
df_statistics_death_rate=pd.DataFrame(statistics_death_rate)
df_statistics_death_rate.index=["United States","United Kingdom","Japan","India","Germany","France","China"]
df_statistics_death_rate.index.name="Country"
df_statistics_death_rate.columns.name="Statistics"
df_statistics_death_rate.style.highlight_max(color='')
# Out:
# <style type="text/css">
# #T_3a549_row0_col0, #T_3a549_row0_col1, #T_3a549_row0_col3, #T_3a549_row3_col2 {
#   background-color: ;
# }
# </style>
# <table id="T_3a549_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Average Deaths</th>
#       <th class="col_heading level0 col1" >Median Deaths</th>
#       <th class="col_heading level0 col2" >Maximum Deaths In A Day</th>
#       <th class="col_heading level0 col3" >Total Deaths</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a549_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_3a549_row0_col0" class="data row0 col0" >1233.002928</td>
# ...

# %% [raw]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# A NEW DATABASE

# %%
df_Cases=pd.read_excel("Desktop/Covid_Data.xlsx","Cases",parse_dates=["date"])

# %%
df_Cases.set_index("date",inplace=True)

# %%
df_Cases.head()
# Out:
#            iso_code continent     location  total_cases  new_cases
# date
# 2020-02-24      AFG      Asia  Afghanistan          5.0        5.0
# 2020-02-25      AFG      Asia  Afghanistan          5.0        0.0
# 2020-02-26      AFG      Asia  Afghanistan          5.0        0.0
# 2020-02-27      AFG      Asia  Afghanistan          5.0        0.0
# 2020-02-28      AFG      Asia  Afghanistan          5.0        0.0

# %% [markdown]
# GROUPING THE DATABASE OF THE BIG SEVEN ECONOMIES FOR THE TESTS CONDUCTED

# %%
group_Cases=df_Cases.groupby("location")
group_Cases_India=group_Cases.get_group("India")
group_Cases_US=group_Cases.get_group("United States")
group_Cases_China=group_Cases.get_group("China")
group_Cases_UK=group_Cases.get_group("United Kingdom")
group_Cases_Japan=group_Cases.get_group("Japan")
group_Cases_Germany=group_Cases.get_group("Germany")
group_Cases_France=group_Cases.get_group("France")

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_Cases_India["new_cases"],x=group_Cases_India.index,color="blue",label="India")
sns.lineplot(y=group_Cases_US["new_cases"],x=group_Cases_US.index,color="red",label="US")
sns.lineplot(y=group_Cases_China["new_cases"],x=group_Cases_China.index,color="yellow",label="China")
sns.lineplot(y=group_Cases_UK["new_cases"],x=group_Cases_UK.index,color="black",label="UK")
sns.lineplot(y=group_Cases_Japan["new_cases"],x=group_Cases_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_Cases_Germany["new_cases"],x=group_Cases_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_Cases_France["new_cases"],x=group_Cases_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("New Cases",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Date",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("New Cases In Big Seven Economies",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.show()

# %%
# %matplotlib inline
group_Cases_India["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In India",color="blue",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()
group_Cases_France["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In France",color="purple",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()
group_Cases_UK["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In UK",color="black",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()
group_Cases_US["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In US",color="red",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()
group_Cases_Japan["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In Japan",color="green",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()
group_Cases_Germany["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In Germany",color="orange",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()
group_Cases_China["new_cases"].plot.area(figsize=(10,3),subplots=True,label="Daily Cases In China",color="yellow",stacked=False)
plt.ylabel("Daily Cases")
plt.legend()
plt.show()

# %%
sum_cases_US=group_Cases_US["new_cases"].sum(skipna=True)
max_cases_US=group_Cases_US["new_cases"].max(skipna=True)
min_cases_US=group_Cases_US["new_cases"].min(skipna=True)
mean_cases_US=group_Cases_US["new_cases"].mean(skipna=True)
median_cases_US=group_Cases_US["new_cases"].median(skipna=True)

sum_cases_India=group_Cases_India["new_cases"].sum(skipna=True)
max_cases_India=group_Cases_India["new_cases"].max(skipna=True)
min_cases_India=group_Cases_India["new_cases"].min(skipna=True)
mean_cases_India=group_Cases_India["new_cases"].mean(skipna=True)
median_cases_India=group_Cases_India["new_cases"].median(skipna=True)

sum_cases_UK=group_Cases_UK["new_cases"].sum(skipna=True)
max_cases_UK=group_Cases_UK["new_cases"].max(skipna=True)
min_cases_UK=group_Cases_UK["new_cases"].min(skipna=True)
mean_cases_UK=group_Cases_UK["new_cases"].mean(skipna=True)
median_cases_UK=group_Cases_UK["new_cases"].median(skipna=True)

sum_cases_France=group_Cases_France["new_cases"].sum(skipna=True)
max_cases_France=group_Cases_France["new_cases"].max(skipna=True)
min_cases_France=group_Cases_France["new_cases"].min(skipna=True)
mean_cases_France=group_Cases_France["new_cases"].mean(skipna=True)
median_cases_France=group_Cases_France["new_cases"].median(skipna=True)

sum_cases_Japan=group_Cases_Japan["new_cases"].sum(skipna=True)
max_cases_Japan=group_Cases_Japan["new_cases"].max(skipna=True)
min_cases_Japan=group_Cases_Japan["new_cases"].min(skipna=True)
mean_cases_Japan=group_Cases_Japan["new_cases"].mean(skipna=True)
median_cases_Japan=group_Cases_Japan["new_cases"].median(skipna=True)

sum_cases_Germany=group_Cases_Germany["new_cases"].sum(skipna=True)
max_cases_Germany=group_Cases_Germany["new_cases"].max(skipna=True)
min_cases_Germany=group_Cases_Germany["new_cases"].min(skipna=True)
mean_cases_Germany=group_Cases_Germany["new_cases"].mean(skipna=True)
median_Cases_Germany=group_Cases_Germany["new_cases"].median(skipna=True)

sum_cases_China=group_Cases_China["new_cases"].sum(skipna=True)
max_cases_China=group_Cases_China["new_cases"].max(skipna=True)
min_cases_China=group_Cases_China["new_cases"].min(skipna=True)
mean_cases_China=group_Cases_China["new_cases"].mean(skipna=True)
median_Cases_China=group_Cases_China["new_cases"].median(skipna=True)

# %%
sum_cases_in_big_seven=[sum_cases_China,sum_cases_France,sum_cases_Germany,sum_cases_India,sum_cases_Japan,sum_cases_UK,sum_cases_US]
max_cases_in_big_seven=[max_cases_China,max_cases_France,max_cases_Germany,max_cases_India,max_cases_Japan,max_cases_UK,max_cases_US]
min_cases_in_big_seven=[min_cases_China,min_cases_France,min_cases_Germany,min_cases_India,min_cases_Japan,min_cases_UK,min_cases_US]
median_cases_in_big_seven=[median_Cases_China,median_cases_France,median_Cases_Germany,median_cases_India,median_cases_Japan,median_cases_UK,median_cases_US]
mean_cases_in_big_seven=[mean_cases_China,mean_cases_France,mean_cases_Germany,mean_cases_India,mean_cases_Japan,mean_cases_UK,mean_cases_US]

# %%
statistics_cases={
    "Total cases":sum_cases_in_big_seven,
    "Maximum cases in a day":max_cases_in_big_seven,
    "Minimum cases in a day":min_cases_in_big_seven,
    "Median cases":median_cases_in_big_seven,
    "Average cases":mean_cases_in_big_seven
}

# %%
df_statistics_cases=pd.DataFrame(statistics_cases,index=["China","France","Germany","India","Japan","UK","US"])
df_statistics_cases.index.name="Country"
df_statistics_cases.columns.name="Statistics"
range_cases=df_statistics_cases["Maximum cases in a day"]-df_statistics_cases["Minimum cases in a day"]
df_statistics_cases.insert(3,"Range of Cases",range_cases)
rankings_case_wise=df_statistics_cases["Average cases"].rank(ascending=False)
df_statistics_cases.insert(6,"Average Cases Rankings",rankings_case_wise)
df_statistics_cases.style.highlight_max(color='orange')
# Out:
# <style type="text/css">
# #T_c1069_row0_col6, #T_c1069_row3_col2, #T_c1069_row4_col2, #T_c1069_row6_col0, #T_c1069_row6_col1, #T_c1069_row6_col2, #T_c1069_row6_col3, #T_c1069_row6_col4, #T_c1069_row6_col5 {
#   background-color: orange;
# }
# </style>
# <table id="T_c1069_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Total cases</th>
#       <th class="col_heading level0 col1" >Maximum cases in a day</th>
#       <th class="col_heading level0 col2" >Minimum cases in a day</th>
#       <th class="col_heading level0 col3" >Range of Cases</th>
#       <th class="col_heading level0 col4" >Median cases</th>
#       <th class="col_heading level0 col5" >Average cases</th>
#       <th class="col_heading level0 col6" >Average Cases Rankings</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %%
group_cases_continent=df_Cases.groupby(["continent"])
asia_cases=group_cases_continent.get_group("Asia")
asia_cases_mean=asia_cases["new_cases"].mean(skipna=True)
africa_cases=group_cases_continent.get_group("Africa")
africa_cases_mean=africa_cases["new_cases"].mean(skipna=True)
europe_cases=group_cases_continent.get_group("Europe")
europe_cases_mean=europe_cases["new_cases"].mean(skipna=True)
north_america_cases=group_cases_continent.get_group("North America")
north_america_cases_mean=north_america_cases["new_cases"].mean(skipna=True)
south_america_cases=group_cases_continent.get_group("South America")
south_america_cases_mean=south_america_cases["new_cases"].mean(skipna=True)
oceania_cases=group_cases_continent.get_group("Oceania")
oceania_cases_mean=oceania_cases["new_cases"].mean(skipna=True)

# %%
mean_cases_continent=[africa_cases_mean,asia_cases_mean,europe_cases_mean,north_america_cases_mean,oceania_cases_mean,south_america_cases_mean]
mean_cases_continent_dict={
    "Average Cases":mean_cases_continent
}
df_mean_cases_continent=pd.DataFrame(mean_cases_continent_dict)

# %%
# %matplotlib inline
df_mean_cases_continent.index=["Africa","Asia","Europe","North America","Oceania","South America"]
df_mean_cases_continent.plot(kind="bar",color=["red"],hatch=["o"],edgecolor="white")
plt.xticks(rotation=20)
plt.title("Average Cases Across The Continents")
plt.show()

# %% [markdown]
# _____________________________________________________________________________________________________

# %% [markdown]
# VEWING THE DATABASE

# %%
df_Vaccinations=pd.read_excel("Desktop/Covid_Data.xlsx","Vaccinations",parse_dates=["date"])

# %%
df_Vaccinations.set_index("date",inplace=True)

# %%
df_Vaccinations.head()
# Out:
#            iso_code continent     location  total_vaccinations  \
# date
# 2020-02-24      AFG      Asia  Afghanistan                 NaN
# 2020-02-25      AFG      Asia  Afghanistan                 NaN
# 2020-02-26      AFG      Asia  Afghanistan                 NaN
# 2020-02-27      AFG      Asia  Afghanistan                 NaN
# 2020-02-28      AFG      Asia  Afghanistan                 NaN
#
#             people_vaccinated  people_fully_vaccinated  total_boosters  \
# date
# 2020-02-24                NaN                      NaN             NaN
# 2020-02-25                NaN                      NaN             NaN
# 2020-02-26                NaN                      NaN             NaN
# 2020-02-27                NaN                      NaN             NaN
# 2020-02-28                NaN                      NaN             NaN
#
#             new_vaccinations
# date
# 2020-02-24               NaN
# 2020-02-25               NaN
# 2020-02-26               NaN
# ...

# %%
df_Vaccinations.drop(["total_vaccinations","total_boosters","new_vaccinations"],axis=1,inplace=True)

# %%
group_Vaccinations=df_Vaccinations.groupby("location")
group_Vaccinations_India=group_Vaccinations.get_group("India")
group_Vaccinations_France=group_Vaccinations.get_group("France")
group_Vaccinations_Germany=group_Vaccinations.get_group("Germany")
group_Vaccinations_US=group_Vaccinations.get_group("United States")
group_Vaccinations_UK=group_Vaccinations.get_group("United Kingdom")
group_Vaccinations_China=group_Vaccinations.get_group("China")
group_Vaccinations_Japan=group_Vaccinations.get_group("Japan")

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_Vaccinations_India["people_vaccinated"],x=group_Vaccinations_India.index,color="blue",label="India")
sns.lineplot(y=group_Vaccinations_US["people_vaccinated"],x=group_Vaccinations_US.index,color="red",label="US")
sns.lineplot(y=group_Vaccinations_China["people_vaccinated"],x=group_Vaccinations_China.index,color="yellow",label="China")
sns.lineplot(y=group_Vaccinations_UK["people_vaccinated"],x=group_Vaccinations_UK.index,color="black",label="UK")
sns.lineplot(y=group_Vaccinations_Japan["people_vaccinated"],x=group_Vaccinations_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_Vaccinations_Germany["people_vaccinated"],x=group_Vaccinations_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_Vaccinations_France["people_vaccinated"],x=group_Vaccinations_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("People Vaccinated",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Date",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("People Vaccinated In Big Seven Cumulative Graph",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.show()

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=group_Vaccinations_India["people_fully_vaccinated"],x=group_Vaccinations_India.index,color="blue",label="India")
sns.lineplot(y=group_Vaccinations_US["people_fully_vaccinated"],x=group_Vaccinations_US.index,color="red",label="US")
sns.lineplot(y=group_Vaccinations_China["people_fully_vaccinated"],x=group_Vaccinations_China.index,color="yellow",label="China")
sns.lineplot(y=group_Vaccinations_UK["people_fully_vaccinated"],x=group_Vaccinations_UK.index,color="black",label="UK")
sns.lineplot(y=group_Vaccinations_Japan["people_fully_vaccinated"],x=group_Vaccinations_Japan.index,color="green",label="Japan")
sns.lineplot(y=group_Vaccinations_Germany["people_fully_vaccinated"],x=group_Vaccinations_Germany.index,color="orange",label="Germany")
sns.lineplot(y=group_Vaccinations_France["people_fully_vaccinated"],x=group_Vaccinations_France.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("People Fully Vaccinated",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Date",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title("People Fully Vaccinated In Big Seven Cumulative Graph",fontname="Comic Sans MS",size=10,fontstyle="italic")
plt.show()

# %%
china_group_vaccinations_dropna=group_Vaccinations_China.dropna()
china_people_vaccinated_with_one_vaccines=china_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
china_people_fully_vaccinated_with_vaccines=china_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]
france_group_vaccinations_dropna=group_Vaccinations_France.dropna()
france_people_vaccinated_with_one_vaccines=france_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
france_people_fully_vaccinated_with_vaccines=france_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]
india_group_vaccinations_dropna=group_Vaccinations_India.dropna()
india_people_vaccinated_with_one_vaccines=india_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
india_people_fully_vaccinated_with_vaccines=india_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]
germany_group_vaccinations_dropna=group_Vaccinations_Germany.dropna()
germany_people_vaccinated_with_one_vaccines=germany_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
germany_people_fully_vaccinated_with_vaccines=germany_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]
japan_group_vaccinations_dropna=group_Vaccinations_Japan.dropna()
japan_people_vaccinated_with_one_vaccines=japan_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
japan_people_fully_vaccinated_with_vaccines=japan_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]
UK_group_vaccinations_dropna=group_Vaccinations_UK.dropna()
UK_people_vaccinated_with_one_vaccines=UK_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
UK_people_fully_vaccinated_with_vaccines=UK_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]
US_group_vaccinations_dropna=group_Vaccinations_US.dropna()
US_people_vaccinated_with_one_vaccines=US_group_vaccinations_dropna["people_vaccinated"].iloc[-1]
US_people_fully_vaccinated_with_vaccines=US_group_vaccinations_dropna["people_fully_vaccinated"].iloc[-1]

# %%
people_partially_vaccinated_total=[china_people_vaccinated_with_one_vaccines,france_people_vaccinated_with_one_vaccines,india_people_vaccinated_with_one_vaccines,germany_people_vaccinated_with_one_vaccines,japan_people_vaccinated_with_one_vaccines,UK_people_vaccinated_with_one_vaccines,US_people_vaccinated_with_one_vaccines ]

people_fully_vaccinated_total=[china_people_fully_vaccinated_with_vaccines,france_people_fully_vaccinated_with_vaccines,india_people_fully_vaccinated_with_vaccines,germany_people_fully_vaccinated_with_vaccines,japan_people_fully_vaccinated_with_vaccines,UK_people_fully_vaccinated_with_vaccines,US_people_fully_vaccinated_with_vaccines]

# %%
statistics_vaccination={
    "Partially Vaccinated":people_partially_vaccinated_total,
    "Fully Vaccinated":people_fully_vaccinated_total
}

# %%
df_statistics_vaccines=pd.DataFrame(statistics_vaccination)
df_statistics_vaccines.index=["China","France","India","Germany","Japan","UK","US"]
df_statistics_vaccines.name="Big Seven Economies"
df_statistics_vaccines.index.name="Country"
df_statistics_vaccines.columns.name="Statistics"
df_statistics_vaccines.style.highlight_max(color="cyan")
# Out:
# <style type="text/css">
# #T_91795_row0_col0, #T_91795_row0_col1 {
#   background-color: cyan;
# }
# </style>
# <table id="T_91795_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Partially Vaccinated</th>
#       <th class="col_heading level0 col1" >Fully Vaccinated</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91795_level0_row0" class="row_heading level0 row0" >China</th>
#       <td id="T_91795_row0_col0" class="data row0 col0" >1262264000.000000</td>
#       <td id="T_91795_row0_col1" class="data row0 col1" >1215878000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_91795_level0_row1" class="row_heading level0 row1" >France</th>
#       <td id="T_91795_row1_col0" class="data row1 col0" >53175741.000000</td>
# ...

# %%
continents_vaccination_group=df_Vaccinations.groupby("continent")
Asia_vaccinations_group=continents_vaccination_group.get_group("Asia")
Africa_vaccinations_group=continents_vaccination_group.get_group("Africa")
South_America_vaccinations_group=continents_vaccination_group.get_group("South America")
North_America_vaccinations_group=continents_vaccination_group.get_group("North America")
Oceania_vaccinations_group=continents_vaccination_group.get_group("Oceania")

# %%
Asia_partially_vaccinated=Asia_vaccinations_group["people_vaccinated"].mean(skipna=True)
Asia_fully_vaccinated=Asia_vaccinations_group["people_fully_vaccinated"].mean(skipna=True)

Africa_partially_vaccinated=Africa_vaccinations_group["people_vaccinated"].mean(skipna=True)
Africa_fully_vaccinated=Africa_vaccinations_group["people_fully_vaccinated"].mean(skipna=True)

North_America_partially_vaccinated=North_America_vaccinations_group["people_vaccinated"].mean(skipna=True)
North_America_vaccinated=North_America_vaccinations_group["people_fully_vaccinated"].mean(skipna=True)

South_America_partially_vaccinated=South_America_vaccinations_group["people_vaccinated"].mean(skipna=True)
South_America_fully_vaccinated=South_America_vaccinations_group["people_fully_vaccinated"].mean(skipna=True)

Oceania_partially_vaccinated=Africa_vaccinations_group["people_vaccinated"].mean(skipna=True)
Oceania_fully_vaccinated=Africa_vaccinations_group["people_fully_vaccinated"].mean(skipna=True)

# %%
Continents_partially_vaccinated_details=[Asia_partially_vaccinated,Africa_partially_vaccinated,Oceania_partially_vaccinated,North_America_partially_vaccinated,South_America_partially_vaccinated]
Continents_fully_vaccinated_details=[Asia_fully_vaccinated,Africa_fully_vaccinated,Oceania_fully_vaccinated,North_America_vaccinated,South_America_fully_vaccinated]

# %%
statistics_continents_vaccinations={
    "Partially Vaccinated":Continents_partially_vaccinated_details,
    "Fully Vaccinated":Continents_fully_vaccinated_details
}

# %%
df_continents_vaccinations=pd.DataFrame(statistics_continents_vaccinations)
df_continents_vaccinations.index=["Asia","Africa","Oceania","North America","South America"]
df_continents_vaccinations.index.name="Continents"
df_continents_vaccinations.columns.name="Statistics"
df_continents_vaccinations.style.highlight_max(color="green")
# Out:
# <style type="text/css">
# #T_eb920_row0_col0, #T_eb920_row0_col1 {
#   background-color: green;
# }
# </style>
# <table id="T_eb920_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Partially Vaccinated</th>
#       <th class="col_heading level0 col1" >Fully Vaccinated</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Continents</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb920_level0_row0" class="row_heading level0 row0" >Asia</th>
#       <td id="T_eb920_row0_col0" class="data row0 col0" >26976781.677255</td>
#       <td id="T_eb920_row0_col1" class="data row0 col1" >18439504.739476</td>
#     </tr>
#     <tr>
#       <th id="T_eb920_level0_row1" class="row_heading level0 row1" >Africa</th>
#       <td id="T_eb920_row1_col0" class="data row1 col0" >2321659.798635</td>
# ...

# %%
# %matplotlib inline
df_continents_vaccinations["Partially Vaccinated"].plot(kind="bar",color=["red","green","yellow","green","green"],hatch="*")
plt.xticks(rotation=20)
plt.title("Partially Vaccinated by Continents")
plt.show()

# %%
# %matplotlib inline
df_continents_vaccinations["Fully Vaccinated"].plot(kind="bar",color="green",hatch=["----","-","-","-","-"])
plt.xticks(rotation=20)
plt.title("Fully Vaccinated by Continents")
plt.show()

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# VEIWING THE DATABASE

# %%
df_Population_Health_Parameters=pd.read_excel("Desktop/Covid_Data.xlsx","Population Health Parameters",parse_dates=["date"])

# %%
df_Population_Health_Parameters.set_index("date",inplace=True)

# %%
df_Population_Health_Parameters.head()
# Out:
#            iso_code continent     location  gdp_per_capita  extreme_poverty  \
# date
# 2020-02-24      AFG      Asia  Afghanistan        1803.987              NaN
# 2020-02-25      AFG      Asia  Afghanistan        1803.987              NaN
# 2020-02-26      AFG      Asia  Afghanistan        1803.987              NaN
# 2020-02-27      AFG      Asia  Afghanistan        1803.987              NaN
# 2020-02-28      AFG      Asia  Afghanistan        1803.987              NaN
#
#             cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# date
# 2020-02-24                597.029                 9.59             NaN
# 2020-02-25                597.029                 9.59             NaN
# 2020-02-26                597.029                 9.59             NaN
# 2020-02-27                597.029                 9.59             NaN
# 2020-02-28                597.029                 9.59             NaN
#
# ...

# %%
Population_Health_Parameters_Group=df_Population_Health_Parameters.groupby("location")
India_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("India")
US_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("United States")
UK_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("United Kingdom")
Japan_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("Japan")
China_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("China")
Germany_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("Germany")
France_Population_Health_Parameters_Group=Population_Health_Parameters_Group.get_group("France")

# %%
gdp_per_capita_big_seven=[India_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1],Germany_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1],China_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1],France_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1],Japan_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1],US_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1],UK_Population_Health_Parameters_Group["gdp_per_capita"].iloc[1]]

# %%
# IN PERCENTAGES
extreme_poverty_big_seven=[India_Population_Health_Parameters_Group["extreme_poverty"].iloc[1],Germany_Population_Health_Parameters_Group["extreme_poverty"].iloc[1],China_Population_Health_Parameters_Group["extreme_poverty"].iloc[1],France_Population_Health_Parameters_Group["extreme_poverty"].iloc[1],Japan_Population_Health_Parameters_Group["extreme_poverty"].iloc[1],US_Population_Health_Parameters_Group["extreme_poverty"].iloc[1],UK_Population_Health_Parameters_Group["extreme_poverty"].iloc[1]]

# %%
diabetes_prevalence_big_seven=[India_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1],Germany_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1],China_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1],France_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1],Japan_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1],US_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1],UK_Population_Health_Parameters_Group["diabetes_prevalence"].iloc[1]]

# %%
cardiovasc_death_rate_big_seven=[India_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1],Germany_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1],China_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1],France_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1],Japan_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1],US_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1],UK_Population_Health_Parameters_Group["cardiovasc_death_rate"].iloc[1]]

# %%
# IN PERCENTAGES 
female_smokers_big_seven=[India_Population_Health_Parameters_Group["female_smokers"].iloc[1],Germany_Population_Health_Parameters_Group["female_smokers"].iloc[1],China_Population_Health_Parameters_Group["female_smokers"].iloc[1],France_Population_Health_Parameters_Group["female_smokers"].iloc[1],Japan_Population_Health_Parameters_Group["female_smokers"].iloc[1],US_Population_Health_Parameters_Group["female_smokers"].iloc[1],UK_Population_Health_Parameters_Group["female_smokers"].iloc[1]]

# %%
# IN PERCENTAGES
male_smokers_big_seven=[India_Population_Health_Parameters_Group["male_smokers"].iloc[1],Germany_Population_Health_Parameters_Group["male_smokers"].iloc[1],China_Population_Health_Parameters_Group["male_smokers"].iloc[1],France_Population_Health_Parameters_Group["male_smokers"].iloc[1],Japan_Population_Health_Parameters_Group["male_smokers"].iloc[1],US_Population_Health_Parameters_Group["female_smokers"].iloc[1],UK_Population_Health_Parameters_Group["male_smokers"].iloc[1]]

# %%
human_development_index_big_seven=[India_Population_Health_Parameters_Group["human_development_index"].iloc[1],Germany_Population_Health_Parameters_Group["human_development_index"].iloc[1],China_Population_Health_Parameters_Group["human_development_index"].iloc[1],France_Population_Health_Parameters_Group["human_development_index"].iloc[1],Japan_Population_Health_Parameters_Group["human_development_index"].iloc[1],US_Population_Health_Parameters_Group["human_development_index"].iloc[1],UK_Population_Health_Parameters_Group["human_development_index"].iloc[1]]

# %%
life_expectancy_big_seven=[India_Population_Health_Parameters_Group["life_expectancy"].iloc[1],Germany_Population_Health_Parameters_Group["life_expectancy"].iloc[1],China_Population_Health_Parameters_Group["life_expectancy"].iloc[1],France_Population_Health_Parameters_Group["life_expectancy"].iloc[1],Japan_Population_Health_Parameters_Group["life_expectancy"].iloc[1],US_Population_Health_Parameters_Group["life_expectancy"].iloc[1],UK_Population_Health_Parameters_Group["life_expectancy"].iloc[1]]

# %%
handwashing_facilities_big_seven=[India_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1],Germany_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1],China_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1],France_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1],Japan_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1],US_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1],UK_Population_Health_Parameters_Group["handwashing_facilities"].iloc[1]]

# %%
icu_patients_big_seven=[India_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True),Germany_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True),China_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True),France_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True),Japan_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True),US_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True),UK_Population_Health_Parameters_Group["icu_patients"].mean(skipna=True)]

# %%
weekly_icu_admissions_big_seven=[India_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True),Germany_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True),China_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True),France_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True),Japan_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True),US_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True),UK_Population_Health_Parameters_Group["weekly_icu_admissions"].mean(skipna=True)]

# %%
weekly_hosp_admissions_big_seven=[India_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True),Germany_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True),China_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True),France_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True),Japan_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True),US_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True),UK_Population_Health_Parameters_Group["weekly_hosp_admissions"].mean(skipna=True)]

# %%
reproduction_rate_big_seven=[India_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True),Germany_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True),China_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True),France_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True),Japan_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True),US_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True),UK_Population_Health_Parameters_Group["reproduction_rate"].mean(skipna=True)]

# %%
Statistics_Population_Parameters={
    "GDP Per Capita":gdp_per_capita_big_seven,
    "Extreme Poverty":extreme_poverty_big_seven,
    "Diabeties Prevalence":diabetes_prevalence_big_seven,
    "Cardiovascular Death Rate":cardiovasc_death_rate_big_seven,
    "Female Smokers": female_smokers_big_seven,
    "Male Smokers":male_smokers_big_seven,
    "Human Development Index":human_development_index_big_seven,
    "Life Expectancy":life_expectancy_big_seven,
    "Hand Washing Facility":handwashing_facilities_big_seven,
    "ICU Patients":icu_patients_big_seven,
    "Weekly ICU Patients":weekly_icu_admissions_big_seven,
    "Weekly Hospital Patients":weekly_hosp_admissions_big_seven,
    "Reproduction Rate":reproduction_rate_big_seven
}

# %%
df_Statistics_population_parameters=pd.DataFrame(Statistics_Population_Parameters)
df_Statistics_population_parameters.index=["India","Germany","China","France","Japan","US","UK"]
df_Statistics_population_parameters.index.name="Continents"
df_Statistics_population_parameters.columns.name="Statistics"
df_Statistics_population_parameters.style.highlight_max(color="cyan")
# Out:
# <style type="text/css">
# #T_21348_row0_col1, #T_21348_row0_col3, #T_21348_row0_col8, #T_21348_row1_col6, #T_21348_row2_col5, #T_21348_row3_col4, #T_21348_row3_col10, #T_21348_row3_col12, #T_21348_row4_col7, #T_21348_row5_col0, #T_21348_row5_col2, #T_21348_row5_col9, #T_21348_row5_col11 {
#   background-color: cyan;
# }
# </style>
# <table id="T_21348_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >GDP Per Capita</th>
#       <th class="col_heading level0 col1" >Extreme Poverty</th>
#       <th class="col_heading level0 col2" >Diabeties Prevalence</th>
#       <th class="col_heading level0 col3" >Cardiovascular Death Rate</th>
#       <th class="col_heading level0 col4" >Female Smokers</th>
#       <th class="col_heading level0 col5" >Male Smokers</th>
#       <th class="col_heading level0 col6" >Human Development Index</th>
#       <th class="col_heading level0 col7" >Life Expectancy</th>
# ...

# %%
# %matplotlib inline
df_Statistics_population_parameters["Human Development Index"].plot(kind="bar",color=["green","red","yellow","yellow","yellow","yellow","yellow"],edgecolor="black",hatch=["o","*","o","o","o","o","o"])
plt.title("Human Development Index",font="Agency FB",size=20,color="black")
plt.xticks(rotation=30)
plt.show()

# %%
# %matplotlib inline
df_Statistics_population_parameters["Reproduction Rate"].plot(kind="bar",color=["red","red","yellow","orange","red","red","red"],edgecolor=["black","black","red","green","black","black","black"],hatch="*")
plt.title("Reproduction Rate",font="Agency FB",size=20,color="black")
plt.xticks(rotation=30)
plt.show()

# %%
# %matplotlib inline
df_Statistics_population_parameters["GDP Per Capita"].plot(kind="bar",color=["blue","green","green","green","green","yellow","green"],edgecolor="black")
plt.title("GDP Per Capita",font="Agency FB",size=20,color="black")
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(dpi=200)
plt.axes(facecolor="lightgrey")
sns.lineplot(y=US_Population_Health_Parameters_Group["icu_patients"],x=US_Population_Health_Parameters_Group.index,color="red",label="US")
sns.lineplot(y=UK_Population_Health_Parameters_Group["icu_patients"],x=UK_Population_Health_Parameters_Group.index,color="black",label="UK")
sns.lineplot(y=Germany_Population_Health_Parameters_Group["icu_patients"],x=Germany_Population_Health_Parameters_Group.index,color="orange",label="Germany")
sns.lineplot(y=France_Population_Health_Parameters_Group["icu_patients"],x=France_Population_Health_Parameters_Group.index,color="purple",label="France")
plt.legend(bbox_to_anchor=(1.1,1),facecolor="lightgrey",edgecolor="black",ncol=2)
plt.ylabel("Paitients",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xlabel("Date",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.xticks(color="black",size=10,rotation=30,fontname="Agency FB")
plt.yticks(color="black",size=10,fontname="Agency FB")
plt.title(" Daily ICU Patients",fontname="Comic Sans MS",fontweight="bold",fontstyle="italic")
plt.show()

# %% [raw]
# _______________________________________________________________________________________________________________________________

# %%
df_Population_Indicators=pd.read_excel("Desktop/Covid_Data.xlsx"," Population_Indicators",parse_dates=["date"])

# %%
df_Population_Indicators.set_index("date",inplace=True)

# %%
Population_Indicators_Group=df_Population_Indicators.groupby("location")

# %%
China_Population_Indicators_Group=Population_Indicators_Group.get_group("China")
France_Population_Indicators_Group=Population_Indicators_Group.get_group("France")
India_Population_Indicators_Group=Population_Indicators_Group.get_group("India")
Germany_Population_Indicators_Group=Population_Indicators_Group.get_group("Germany")
Japan_Population_Indicators_Group=Population_Indicators_Group.get_group("Japan")
US_Population_Indicators_Group=Population_Indicators_Group.get_group("United States")
UK_Population_Indicators_Group=Population_Indicators_Group.get_group("United Kingdom")

# %%
population_big_seven=[India_Population_Indicators_Group["population"].iloc[1],Germany_Population_Indicators_Group["population"].iloc[1],China_Population_Indicators_Group["population"].iloc[1],France_Population_Indicators_Group["population"].iloc[1],Japan_Population_Indicators_Group["population"].iloc[1],US_Population_Indicators_Group["population"].iloc[1],UK_Population_Indicators_Group["population"].iloc[1]]
population_density_big_seven=[India_Population_Indicators_Group["population_density"].iloc[1],Germany_Population_Indicators_Group["population_density"].iloc[1],China_Population_Indicators_Group["population_density"].iloc[1],France_Population_Indicators_Group["population_density"].iloc[1],Japan_Population_Indicators_Group["population_density"].iloc[1],US_Population_Indicators_Group["population_density"].iloc[1],UK_Population_Indicators_Group["population_density"].iloc[1]]
median_age_big_seven=[India_Population_Indicators_Group["median_age"].iloc[1],Germany_Population_Indicators_Group["median_age"].iloc[1],China_Population_Indicators_Group["median_age"].iloc[1],France_Population_Indicators_Group["median_age"].iloc[1],Japan_Population_Indicators_Group["median_age"].iloc[1],US_Population_Indicators_Group["median_age"].iloc[1],UK_Population_Indicators_Group["median_age"].iloc[1]]
aged_65_older_big_seven=[India_Population_Indicators_Group["aged_65_older"].iloc[1],Germany_Population_Indicators_Group["aged_65_older"].iloc[1],China_Population_Indicators_Group["aged_65_older"].iloc[1],France_Population_Indicators_Group["aged_65_older"].iloc[1],Japan_Population_Indicators_Group["aged_65_older"].iloc[1],US_Population_Indicators_Group["aged_65_older"].iloc[1],UK_Population_Indicators_Group["aged_65_older"].iloc[1]]
aged_70_older_big_seven=[India_Population_Indicators_Group["aged_70_older"].iloc[1],Germany_Population_Indicators_Group["aged_70_older"].iloc[1],China_Population_Indicators_Group["aged_70_older"].iloc[1],France_Population_Indicators_Group["aged_70_older"].iloc[1],Japan_Population_Indicators_Group["aged_70_older"].iloc[1],US_Population_Indicators_Group["aged_70_older"].iloc[1],UK_Population_Indicators_Group["aged_70_older"].iloc[1]]

# %%
Statistics_Population_Indicators={
    "Population":population_big_seven,
    "Population Density":population_density_big_seven,
    "Median Age":median_age_big_seven,
    "Above 65 Years":aged_65_older_big_seven,
    "Above 70 Years":aged_70_older_big_seven
}

# %%
df_Statistics_Population_Indicators=pd.DataFrame(Statistics_Population_Indicators)
df_Statistics_Population_Indicators.columns.name="Statistics"
df_Statistics_Population_Indicators.index.name="Country"
df_Statistics_Population_Indicators.index=["India","Germany","China","France","Japan","US","UK"]
df_Statistics_Population_Indicators.style.highlight_max(color="orange")
# Out:
# <style type="text/css">
# #T_b4db9_row0_col1, #T_b4db9_row2_col0, #T_b4db9_row4_col2, #T_b4db9_row4_col3, #T_b4db9_row4_col4 {
#   background-color: orange;
# }
# </style>
# <table id="T_b4db9_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Statistics</th>
#       <th class="col_heading level0 col0" >Population</th>
#       <th class="col_heading level0 col1" >Population Density</th>
#       <th class="col_heading level0 col2" >Median Age</th>
#       <th class="col_heading level0 col3" >Above 65 Years</th>
#       <th class="col_heading level0 col4" >Above 70 Years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4db9_level0_row0" class="row_heading level0 row0" >India</th>
#       <td id="T_b4db9_row0_col0" class="data row0 col0" >1393409033.000000</td>
#       <td id="T_b4db9_row0_col1" class="data row0 col1" >450.419000</td>
#       <td id="T_b4db9_row0_col2" class="data row0 col2" >28.200000</td>
# ...

# %%
# %matplotlib inline
df_Statistics_Population_Indicators["Population"].plot(kind="bar",color="red",hatch=["","","*","----","","",""],edgecolor=["black","black","yellow","grey","black","black"])
plt.xticks(rotation=20)
plt.xlabel("Country")
plt.title("Population within big seven economies")
plt.show()

# %%
# %matplotlib inline
df_Statistics_Population_Indicators["Population Density"].plot(kind="bar",color=["black","black","black","black","black","cyan","black"],hatch=["o","","","","","*",""],edgecolor=["cyan","black","black","black","cyan","black"])
plt.xticks(rotation=20)
plt.xlabel("Country")
plt.title("Population Density within big seven economies")
plt.show()

# %%
# %matplotlib inline
df_Statistics_Population_Indicators["Median Age"].plot(kind="bar",color=["orange","green","green","green","red","green","green"],edgecolor=["black","black","black","black","black","black"])
plt.xticks(rotation=20)
plt.xlabel("Country")
plt.title("Median Age within big seven economies")
plt.show()

# %%
# %matplotlib inline
df_Statistics_Population_Indicators["Above 65 Years"].plot(kind="bar",color=["red","green","green","green","yellow","green","green"],edgecolor=["black","black","black","black","green","black"],hatch=["*","","","","*","",""])
plt.xticks(rotation=20)
plt.xlabel("Country")
plt.title("Above 65 Years within big seven economies")
plt.show()

# %%
# %matplotlib inline
df_Statistics_Population_Indicators["Above 70 Years"].plot(kind="bar",color=["yellow","orange","orange","orange","yellow","orange","orange"],edgecolor=["red","black","black","black","blue","black"],hatch=["x","","","","x","",""])
plt.xticks(rotation=20)
plt.xlabel("Country")
plt.title("Above 65 Years within big seven economies")
plt.show()
